# %%
from genere_rapport.notebook_to_rapport import notebook_to_html_plotly

# %%
pat_notebook = "/Users/amadyfarbasy/Downloads/original/ism/DataVisualisation/data_viz_finance.ipynb"
direction_sortie = "/Users/amadyfarbasy/Downloads/original/ism/DataVisualisation"
notebook_to_html_plotly(pat_notebook, direction_sortie)
# Out:
# '/Users/amadyfarbasy/Downloads/original/ism/DataVisualisation/data_viz_finance.html'
